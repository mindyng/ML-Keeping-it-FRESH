# %% [markdown]
# <a href="https://colab.research.google.com/github/mindyng/ML-Keeping-it-FRESH/blob/master/RNN_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Original code is from https://github.com/spro/practical-pytorch
import time
import math
import torch
import torch.nn as nn
from torch.autograd import Variable
from torch.utils.data import DataLoader

#from name_dataset import NameDataset
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence

### from name_dataset.py
import torch
import numpy as np
from torch.autograd import Variable
from torch.utils.data import Dataset, DataLoader
import csv
import gzip


class NameDataset(Dataset):
    """ Diabetes dataset."""

    # Initialize your data, download, etc.
    def __init__(self, is_train_set=False):
        filename = '/content/sample_data/names_train.csv.gz' if is_train_set else '/content/sample_data/names_test.csv.gz'
        with gzip.open(filename, "rt") as f:
            reader = csv.reader(f)
            rows = list(reader)

        self.names = [row[0] for row in rows]
        self.countries = [row[1] for row in rows]
        self.len = len(self.countries)

        self.country_list = list(sorted(set(self.countries)))

    def __getitem__(self, index):
        return self.names[index], self.countries[index]

    def __len__(self):
        return self.len

    def get_countries(self):
        return self.country_list

    def get_country(self, id):
        return self.country_list[id]

    def get_country_id(self, country):
        return self.country_list.index(country)

# Test the loader
if __name__ == "__main__":
    dataset = NameDataset(False)
    print(dataset.get_countries())
    print(dataset.get_country(3))
    print(dataset.get_country_id('Korean'))

    train_loader = DataLoader(dataset=dataset,
                              batch_size=10,
                              shuffle=True)

    print(len(train_loader.dataset))
    for epoch in range(2):
        for i, (names, countries) in enumerate(train_loader):
            # Run your training process
            print(epoch, i, "names", names, "countries", countries)

###

# Parameters and DataLoaders
HIDDEN_SIZE = 100
N_LAYERS = 2
BATCH_SIZE = 256
N_EPOCHS = 100

test_dataset = NameDataset(is_train_set=False)
test_loader = DataLoader(dataset=test_dataset,
                         batch_size=BATCH_SIZE, shuffle=True)


train_dataset = NameDataset(is_train_set=True)
train_loader = DataLoader(dataset=train_dataset,
                          batch_size=BATCH_SIZE, shuffle=True)

N_COUNTRIES = len(train_dataset.get_countries())
print(N_COUNTRIES, "countries")
N_CHARS = 128  # ASCII


# Some utility functions
def time_since(since):
    s = time.time() - since
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def create_variable(tensor):
    # Do cuda() before wrapping with variable
    if torch.cuda.is_available():
        return Variable(tensor.cuda())
    else:
        return Variable(tensor)


# pad sequences and sort the tensor
def pad_sequences(vectorized_seqs, seq_lengths, countries):
    seq_tensor = torch.zeros((len(vectorized_seqs), seq_lengths.max())).long()
    for idx, (seq, seq_len) in enumerate(zip(vectorized_seqs, seq_lengths)):
        seq_tensor[idx, :seq_len] = torch.LongTensor(seq)

    # Sort tensors by their length
    seq_lengths, perm_idx = seq_lengths.sort(0, descending=True)
    seq_tensor = seq_tensor[perm_idx]

    # Also sort the target (countries) in the same order
    target = countries2tensor(countries)
    if len(countries):
        target = target[perm_idx]

    # Return variables
    # DataParallel requires everything to be a Variable
    return create_variable(seq_tensor), \
        create_variable(seq_lengths), \
        create_variable(target)


# Create necessary variables, lengths, and target
def make_variables(names, countries):
    sequence_and_length = [str2ascii_arr(name) for name in names]
    vectorized_seqs = [sl[0] for sl in sequence_and_length]
    seq_lengths = torch.LongTensor([sl[1] for sl in sequence_and_length])
    return pad_sequences(vectorized_seqs, seq_lengths, countries)


def str2ascii_arr(msg):
    arr = [ord(c) for c in msg]
    return arr, len(arr)


def countries2tensor(countries):
    country_ids = [train_dataset.get_country_id(
        country) for country in countries]
    return torch.LongTensor(country_ids)


class RNNClassifier(nn.Module):
    # Our model

    def __init__(self, input_size, hidden_size, output_size, n_layers=1, bidirectional=True):
        super(RNNClassifier, self).__init__()
        self.hidden_size = hidden_size
        self.n_layers = n_layers
        self.n_directions = int(bidirectional) + 1

        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size, n_layers,
                          bidirectional=bidirectional)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, input, seq_lengths):
        # Note: we run this all at once (over the whole input sequence)
        # input shape: B x S (input size)
        # transpose to make S(sequence) x B (batch)
        input = input.t()
        batch_size = input.size(1)

        # Make a hidden
        hidden = self._init_hidden(batch_size)

        # Embedding S x B -> S x B x I (embedding size)
        embedded = self.embedding(input)

        # Pack them up nicely
        gru_input = pack_padded_sequence(
            embedded, seq_lengths.data.cpu().numpy())

        # To compact weights again call flatten_parameters().
        self.gru.flatten_parameters()
        output, hidden = self.gru(gru_input, hidden)

        # Use the last layer output as FC's input
        # No need to unpack, since we are going to use hidden
        fc_output = self.fc(hidden[-1])
        return fc_output

    def _init_hidden(self, batch_size):
        hidden = torch.zeros(self.n_layers * self.n_directions,
                             batch_size, self.hidden_size)
        return create_variable(hidden)


# Train cycle
def train():
    total_loss = 0

    for i, (names, countries) in enumerate(train_loader, 1):
        input, seq_lengths, target = make_variables(names, countries)
        output = classifier(input, seq_lengths)

        loss = criterion(output, target)
        total_loss += loss.data

        classifier.zero_grad()
        loss.backward()
        optimizer.step()

        if i % 10 == 0:
            print('[{}] Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.2f}'.format(
                time_since(start), epoch,  i *
                len(names), len(train_loader.dataset),
                100. * i * len(names) / len(train_loader.dataset),
                total_loss / i * len(names)))

    return total_loss


# Testing cycle
def test(name=None):
    # Predict for a given name
    if name:
        input, seq_lengths, target = make_variables([name], [])
        output = classifier(input, seq_lengths)
        pred = output.data.max(1, keepdim=True)[1]
        country_id = pred.cpu().numpy()[0][0]
        print(name, "is", train_dataset.get_country(country_id))
        return

    print("evaluating trained model ...")
    correct = 0
    train_data_size = len(test_loader.dataset)

    for names, countries in test_loader:
        input, seq_lengths, target = make_variables(names, countries)
        output = classifier(input, seq_lengths)
        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(target.data.view_as(pred)).cpu().sum()

    print('\nTest set: Accuracy: {}/{} ({:.0f}%)\n'.format(
        correct, train_data_size, 100. * correct / train_data_size))


if __name__ == '__main__':

    classifier = RNNClassifier(N_CHARS, HIDDEN_SIZE, N_COUNTRIES, N_LAYERS)
    if torch.cuda.device_count() > 1:
        print("Let's use", torch.cuda.device_count(), "GPUs!")
        # dim = 0 [33, xxx] -> [11, ...], [11, ...], [11, ...] on 3 GPUs
        classifier = nn.DataParallel(classifier)

    if torch.cuda.is_available():
        classifier.cuda()

    optimizer = torch.optim.Adam(classifier.parameters(), lr=0.001)
    criterion = nn.CrossEntropyLoss()

    start = time.time()
    print("Training for %d epochs..." % N_EPOCHS)
    for epoch in range(1, N_EPOCHS + 1):
        # Train cycle
        train()

        # Testing
        test()

        # Testing several samples
        test("Sung")
        test("Jungwoo")
        test("Soojin")
        test("Nako")
# Out:
# ['Arabic', 'Chinese', 'Czech', 'Dutch', 'English', 'French', 'German', 'Greek', 'Irish', 'Italian', 'Japanese', 'Korean', 'Polish', 'Portuguese', 'Russian', 'Scottish', 'Spanish', 'Vietnamese']
# Dutch
# 11
# 6700
# 0 0 names ('Pugliese', 'Derkachenko', 'Janbarisov', 'Gadsden', 'Atherley', 'Awturhanoff', 'Issa', 'Shamoon', 'Abadi', 'Hausler') countries ('Italian', 'Russian', 'Russian', 'English', 'English', 'Russian', 'Arabic', 'Arabic', 'Arabic', 'German')
# 0 1 names ('Kasuse', 'Schlusser', 'Kunikida', 'Saiko', 'Quraishi', 'Schwangau', 'Jigin', 'Oriol', 'Kaczka', 'Mcbain') countries ('Japanese', 'German', 'Japanese', 'Russian', 'Arabic', 'German', 'Russian', 'Spanish', 'Polish', 'English')
# 0 2 names ('Ferreira', 'Couch', 'Maloof', 'Shamshin', 'Zastavsky', 'Favager', 'Tsehmistrenko', 'Antoun', 'Tzeimen', 'Palzewicz') countries ('Portuguese', 'English', 'Arabic', 'Russian', 'Russian', 'French', 'Russian', 'Arabic', 'Russian', 'Czech')
# 0 3 names ('Marfusalov', 'Kalenik', 'Halo', 'Shigeki', 'Mochulsky', 'Yakuschenko', 'Belman', 'Bilmus', 'Jansen', 'Jafarov') countries ('Russian', 'Russian', 'Russian', 'Japanese', 'Russian', 'Russian', 'Russian', 'Russian', 'English', 'Russian')
# 0 4 names ("Dar'In", 'Maestri', 'Vyalkov', 'Bekuh', 'Michel', 'Mikhoels', 'Bellamy', 'Poholkov', 'Grokhar', 'Chuhonkin') countries ('Russian', 'Italian', 'Russian', 'Russian', 'Polish', 'Russian', 'English', 'Russian', 'Russian', 'Russian')
# 0 5 names ('Gutteridge', 'Gulin', 'Tsegoev', 'Hitrun', 'Yagovenko', 'Salter', 'Amari', 'Jeravin', 'Tsukatani', 'Ohme') countries ('English', 'Russian', 'Russian', 'Russian', 'Russian', 'English', 'Arabic', 'Russian', 'Japanese', 'German')
# 0 6 names ('Zhurbin', 'Awrorin', 'Greenshields', 'Redman', 'Newman', 'Khan', 'Kassis', 'Kachnov', 'Atiyeh', 'Best') countries ('Russian', 'Russian', 'English', 'English', 'English', 'English', 'Arabic', 'Russian', 'Arabic', 'English')
# 0 7 names ('Katzebin', 'Takudome', 'Tchalyshev', 'Avduevsky', 'Dora', 'Gu', 'Hachapuridze', 'Kanaan', 'Fukunaka', 'Dikovenko') countries ('Russian', 'Japanese', 'Russian', 'Russian', 'English', 'Korean', 'Russian', 'Arabic', 'Japanese', 'Russian')
# 0 8 names ('Proctor', 'Mcgregor', 'Baikalov', 'Lajentsev', 'Grigoriev', 'Arian', 'Vyalykh', 'Yun', 'To The First Page', 'Dargevich') countries ('English', 'Scottish', 'Russian', 'Russian', 'Russian', 'Arabic', 'Russian', 'Chinese', 'Russian', 'Russian')
# 0 9 names ('Marchanukov', 'Teunissen', 'Zhukovin', 'Monomonoi', 'Trumbauer', 'Tannous', 'Lohno', 'Solo', 'Aboimov', 'Clineburg') countries ('Russian', 'Dutch', 'Russian', 'Japanese', 'German', 'Arabic', 'Russian', 'Spanish', 'Russian', 'Czech')
# 0 10 names ('Gulai', 'Rakhmanov', 'Gavin', 'Tsapov', 'Pakholkov', 'To The First Page', 'Alder', 'Lupei', 'Yakovchenko', 'Eltsin') countries ('Russian', 'Russian', 'English', 'Russian', 'Russian', 'Russian', 'English', 'Russian', 'Russian', 'Russian')
# 0 11 names ('Awad', 'Lethbridge', 'Balashov', 'Paramoshin', 'Martov', 'Kalimahi', 'To The First Page', 'Adamczak', 'Agranovich', 'Hudainatov') countries ('Arabic', 'English', 'Russian', 'Russian', 'Russian', 'Russian', 'Russian', 'Polish', 'Russian', 'Russian')
# 0 12 names ('Lezjov', 'Zaloumi', 'Wagner', 'Amin', 'Jukhtanov', 'Vadovski', 'Lennon', 'Hallett', 'Lysko', 'Kahler') countries ('Russian', 'Greek', 'German', 'English', 'Russian', 'Russian', 'English', 'English', 'Russian', 'German')
# 0 13 names ('Caron', 'Dubnov', 'Antar', 'Albrici', 'Arbudu', 'Turov', 'Antohin', 'Chikomasov', 'Beck', 'Stephen') countries ('French', 'Russian', 'Arabic', 'Italian', 'Russian', 'Russian', 'Russian', 'Russian', 'English', 'English')
# 0 14 names ('Mifsud', 'Issa', 'Kauphsman', 'Jestovsky', 'Poshutilin', 'Fashingbauer', 'Doveiko', 'Yatsunov', 'Gladky', 'Abdulladjanov') countries ('Arabic', 'Arabic', 'Czech', 'Russian', 'Russian', 'German', 'Russian', 'Russian', 'Russian', 'Russian')
# 0 15 names ('Vajov', 'Kitson', 'Aitchison', 'Gagulin', 'Bach', 'Train', 'Perrett', 'Rampling', 'Dobryshev', 'Beklenischev') countries ('Russian', 'English', 'English', 'Russian', 'Vietnamese', 'English', 'English', 'English', 'Russian', 'Russian')
# 0 16 names ('Mogilny', 'Moschenko', 'Mikhalkovsky', 'Babakulov', 'Zhadin', 'Boland', 'Yanshin', 'Asghar', 'Eletsky', 'Alhimov') countries ('Russian', 'Russian', 'Russian', 'Russian', 'Russian', 'English', 'Russian', 'Arabic', 'Russian', 'Russian')
# 0 17 names ('Taka', 'Pechenkin', 'Shadid', 'Masih', 'Alberghini', 'Bagimov', 'Weigand', 'Limitovsky', 'Pazhinsky', 'Shan') countries ('Japanese', 'Russian', 'Arabic', 'Arabic', 'Italian', 'Russian', 'German', 'Russian', 'Russian', 'Chinese')
# 0 18 names ('Arnold', 'Demich', 'Gaskell', 'Abadi', 'Govorkov', 'Ashman', 'Mniszech', 'Tovstukha', 'Nuriev', 'Novotny') countries ('English', 'Russian', 'English', 'Arabic', 'Russian', 'English', 'Russian', 'Russian', 'Russian', 'Czech')
# 0 19 names ('Toman', 'Golosnenko', 'Everson', 'Ewin', 'Mocharov', "V'Yun", 'Hanikyan', 'Chersky', 'Jadrov', 'Carroll') countries ('Czech', 'Russian', 'English', 'English', 'Russian', 'Russian', 'Russian', 'Russian', 'Russian', 'English')
# 0 20 names ('Duffy', 'Cove', 'Avvakumov', 'Garcia', 'Khoury', 'Aduloff', 'Zenger', 'Beilin', 'Eglan', 'Abadi') countries ('English', 'English', 'Russian', 'English', 'Arabic', 'Russian', 'Russian', 'Russian', 'English', 'Arabic')
# 0 21 names ('Awduewski', 'Shaldybin', 'Uetake', 'Markushev', 'Finkelson', 'Hazanovich', 'Imerlishvili', 'Shamankov', 'Ryjikh', 'Adrianoff') countries ('Russian', 'Russian', 'Japanese', 'Russian', 'Russian', 'Russian', 'Russian', 'Russian', 'Russian', 'Russian')
# 0 22 names ('Castro', 'Janimov', 'Likhovidov', 'Nahas', 'Barnes', 'Ganim', 'Netsch', 'Quirke', 'Mudra', 'Bindyukov') countries ('Portuguese', 'Russian', 'Russian', 'Arabic', 'English', 'Arabic', 'Czech', 'Irish', 'Czech', 'Russian')
# 0 23 names ('Atiskov', 'Jakhno', 'Masoni', 'Guttuso', 'Hamilton', 'Shalimov', 'Groshkov', 'Mortimer', 'Altimari', 'Abdullaev') countries ('Russian', 'Russian', 'Japanese', 'Italian', 'English', 'Russian', 'Russian', 'English', 'Italian', 'Russian')
# 0 24 names ('Shalko', 'Froltsov', 'Cattaneo', 'Polivka', 'Adkins', 'Moghadam', 'Rzheshevsky', 'Tzelobenok', 'Ader', 'Stoppard') countries ('Russian', 'Russian', 'Italian', 'Russian', 'English', 'Arabic', 'Russian', 'Russian', 'Russian', 'English')
# 0 25 names ('Oirschot', 'Wiesner', 'Bektemirov', 'Espino', 'Chadin', 'Dinapoli', 'Shadid', 'Drew', 'Faltejsek', 'Kanada') countries ('Dutch', 'Czech', 'Russian', 'Spanish', 'Russian', 'Italian', 'Arabic', 'English', 'Czech', 'Japanese')
# 0 26 names ('Shalamanov', 'Kramer', 'Awad', 'Verstin', 'Durasov', 'Makhanov', 'Dzhaldzhireev', 'Torres', 'Juravlenko', 'Schetinkin') countries ('Russian', 'German', 'Arabic', 'Russian', 'Russian', 'Russian', 'Russian', 'English', 'Russian', 'Russian')
# 0 27 names ('Hatuntsev', 'Fintiktikov', 'Zhao', 'Myatishkin', 'Lichnov', 'Gimondi', 'Huranov', 'Zhebelev', 'Wilton', 'Yanagi') countries ('Russian', 'Russian', 'Chinese', 'Russian', 'Russian', 'Italian', 'Russian', 'Russian', 'English', 'Japanese')
# 0 28 names ('Birin', 'Pitomets', 'Mustafa', 'Finik', 'Bazilevich', 'Michalovic', 'Mckenzie', 'Ruzhilo', 'Keeler', 'Purdes') countries ('Russian', 'Russian', 'Arabic', 'Russian', 'Russian', 'Czech', 'Scottish', 'Russian', 'English', 'Czech')
# 0 29 names ('Irvine', 'Baarle', 'Pokhodun', 'Sarkis', 'Pini', 'Liharev', 'Tahan', 'Ruzimatov', 'Yukhimuk', 'Deguchi') countries ('English', 'Dutch', 'Russian', 'Arabic', 'Italian', 'Russian', 'Arabic', 'Russian', 'Russian', 'Japanese')
# 0 30 names ('Kenney', 'Talalykin', 'Jeffers', 'Hugaev', 'Shakhlamov', 'Zunino', 'Paget', 'Ukiyo', 'Rotin', 'Dubman') countries ('English', 'Russian', 'English', 'Russian', 'Russian', 'Italian', 'French', 'Japanese', 'Russian', 'Russian')
# 0 31 names ('Zanetti', 'Jogin', 'Kingman', 'Yuhma', 'Tronko', 'Mozharovsky', 'Vedikhov', 'Leeuwenhoek', 'Bagaryakoff', 'Longo') countries ('Italian', 'Russian', 'English', 'Russian', 'Russian', 'Russian', 'Russian', 'Dutch', 'Russian', 'Italian')
# 0 32 names ('Isa', 'Yakovlenko', 'Portsevsky', 'Belgov', 'Capello', 'Alexander', 'Cingolani', 'Rushbrooke', 'Anofriev', 'Horos') countries ('Arabic', 'Russian', 'Russian', 'Russian', 'Italian', 'English', 'Italian', 'English', 'Russian', 'Russian')
# 0 33 names ('Danshin', 'Shirai', 'Moghadam', 'Vagarshyan', 'Linley', 'Menendez', 'Beltyukov', 'Velsovsky', 'Underwood', 'Jarkih') countries ('Russian', 'Japanese', 'Arabic', 'Russian', 'English', 'Spanish', 'Russian', 'Russian', 'English', 'Russian')
# 0 34 names ('Virekhovsky', 'Kartashev', 'Howells', 'Sarraf', 'Zheludev', 'Fenlon', 'Shaihmurzin', 'Kachalov', 'Vasyanovich', 'Normington') countries ('Russian', 'Russian', 'English', 'Arabic', 'Russian', 'English', 'Russian', 'Russian', 'Russian', 'English')
# 0 35 names ('Baushev', 'Shakhorin', 'Pyrchenko', 'Sayegh', 'Balagula', 'Baz', 'Makukha', 'Aalsburg', "O'Meara", 'Debenham') countries ('Russian', 'Russian', 'Russian', 'Arabic', 'Russian', 'Arabic', 'Russian', 'Dutch', 'Irish', 'English')
# 0 36 names ('Qureshi', 'Balboni', 'Mansour', 'Adyan', 'Sugihara', 'Agranenko', 'Duke', 'Glaister', 'Smets', 'Haik') countries ('Arabic', 'Italian', 'Arabic', 'Russian', 'Japanese', 'Russian', 'English', 'English', 'Dutch', 'Arabic')
# 0 37 names ("O'Reilly", 'Vilchitsky', 'Shelton', 'Shiba', 'Chizhevsky', 'Freud', 'Atyurievsky', 'Chadov', 'Bakhtchivandji', 'Rosenberger') countries ('Irish', 'Russian', 'English', 'Japanese', 'Russian', 'German', 'Russian', 'Russian', 'Russian', 'German')
# 0 38 names ('Dovladbegyan', 'Platt', 'Galkin', 'Nezhdanov', 'Kouri', 'Komatsuzaki', 'Zharsky', 'Glussky', 'Abbakumovsky', 'Squire') countries ('Russian', 'English', 'Russian', 'Russian', 'Arabic', 'Japanese', 'Russian', 'Russian', 'Russian', 'English')
# 0 39 names ('Gori', 'Cloutier', 'Neskrebin', 'Gage', 'Dufour', 'Raihelson', 'Bahmutsky', 'Shakh', 'Pligin', 'Bleskan') countries ('Italian', 'French', 'Russian', 'French', 'French', 'Russian', 'Russian', 'Russian', 'Russian', 'Czech')
# 0 40 names ('Li', 'Haryukov', 'Jilin', 'Mendel', 'Gest', 'Kinsey', 'Babadjanov', 'Jagodinsky', 'Balaban', 'Register') countries ('Russian', 'Russian', 'Russian', 'German', 'Russian', 'English', 'Russian', 'Russian', 'Russian', 'Irish')
# 0 41 names ('Cherchen', 'Abdrahimov', 'Antoshevsky', 'Cham', 'Galochkin', 'Ryzhikh', 'Deryujinsky', 'Goodridge', 'Tarumi', 'Mifsud') countries ('Russian', 'Russian', 'Russian', 'Arabic', 'Russian', 'Russian', 'Russian', 'English', 'Japanese', 'Arabic')
# 0 42 names ('Nicastro', 'Baidin', 'Glukharev', 'Ellrott', 'Ruff', 'Morava', 'Powles', 'Jmelkov', 'Messer', 'Aldworth') countries ('Italian', 'Russian', 'Russian', 'English', 'English', 'Czech', 'English', 'Russian', 'German', 'English')
# 0 43 names ('Winman', 'Kachioni', 'Toyotomi', 'Ragno', 'Priklonsky', 'Boulos', 'Poliev', 'Baichenko', 'Dolejsi', 'Totah') countries ('English', 'Russian', 'Japanese', 'Italian', 'Russian', 'Arabic', 'Russian', 'Russian', 'Czech', 'Arabic')
# 0 44 names ('Volsky', 'Vlasek', 'Mogilensky', 'Duval', 'Molloy', 'Yakubovich', 'Awercheff', 'Czajka', 'Raikov', 'Kerner') countries ('Russian', 'Czech', 'Russian', 'English', 'English', 'Russian', 'Russian', 'Polish', 'Russian', 'German')
# 0 45 names ('Didevich', 'Tchekmarev', 'Otaka', 'Gudovich', 'Gaber', 'Sheluhin', 'Kouri', 'Gerrard', 'Sabbag', 'Khoury') countries ('Russian', 'Russian', 'Japanese', 'Russian', 'Arabic', 'Russian', 'Arabic', 'English', 'Arabic', 'Arabic')
# 0 46 names ('Albats', 'Birger', 'Modzalevsky', 'Yakhnyuk', 'Asfour', 'Dodds', 'Davydov', 'Mccall', "Avak'Yan", 'Purse') countries ('Russian', 'Russian', 'Russian', 'Russian', 'Arabic', 'English', 'Russian', 'English', 'Russian', 'English')
# 0 47 names ('Valitov', 'Shimada', 'Brookfield', 'Luspekaev', 'Gladkih', 'Rakhalsky', 'Mustafa', 'Halstead', 'Nowak', 'Marov') countries ('Russian', 'Japanese', 'English', 'Russian', 'Russian', 'Russian', 'Arabic', 'English', 'English', 'Russian')
# 0 48 names ('Eilers', 'Attia', 'Elebaev', 'Ajogin', 'Onoda', 'Poryvaev', 'Dozortsev', 'Mikhmel', 'Ens', 'Ukhabin') countries ('English', 'Arabic', 'Russian', 'Russian', 'Japanese', 'Russian', 'Russian', 'Russian', 'Russian', 'Russian')
# 0 49 names ('Velikson', 'Gaber', 'Walters', 'St pierre', 'Abrazhevich', 'Tzarakov', 'Zhinkin', 'Langford', 'Parnell', 'Shuai') countries ('Russian', 'Arabic', 'English', 'French', 'Russian', 'Russian', 'Russian', 'English', 'English', 'Chinese')
# 0 50 names ('Keable', 'Fierro', 'Suzuki', 'Darbyshire', 'Vavravsky', 'Duncan', 'Valk', 'Edmunds', 'Abboud', 'Holzknecht') countries ('English', 'Spanish', 'Japanese', 'English', 'Russian', 'Irish', 'Russian', 'English', 'Arabic', 'German')
# 0 51 names ('Badych', 'Thomas', 'Adokhin', 'Babarin', 'Pahlke', 'Anker', 'Fretwell', 'Fairbrace', 'Abgaryan', 'Neumann') countries ('Russian', 'English', 'Russian', 'Russian', 'German', 'English', 'English', 'English', 'Russian', 'German')
# 0 52 names ('Zheliba', 'Zhadanov', 'Castellano', 'Michkov', 'Tinker', 'Ilyukhin', 'Alladee', 'Kijmuta', 'Shammas', 'Dzheladze') countries ('Russian', 'Russian', 'Spanish', 'Russian', 'English', 'Russian', 'English', 'Japanese', 'Arabic', 'Russian')
# 0 53 names ('Fabrichnikov', 'Tallat', 'Nutella', 'Awdiewsky', 'Jares', 'Kartashov', 'Lowrie', 'Hulme', 'Villamov', 'Pasternak') countries ('Russian', 'Russian', 'English', 'Russian', 'Czech', 'Russian', 'English', 'English', 'Russian', 'Polish')
# 0 54 names ('Pazi', 'Homulka', 'Nazari', 'Clough', 'Gasman', 'Schneijders', 'Laterza', 'Mcarthur', 'Cerv', 'Chanov') countries ('Russian', 'Czech', 'Arabic', 'English', 'Russian', 'Dutch', 'Italian', 'English', 'Czech', 'Russian')
# 0 55 names ('Bitar', 'Ichikawa', 'Sakurai', 'Routiyainen', 'Trukhanov', 'Ryjko', 'Judkin', 'Baikoff', 'Yakunichev', 'Levitin') countries ('Arabic', 'Japanese', 'Japanese', 'Russian', 'Russian', 'Russian', 'Russian', 'Russian', 'Russian', 'Russian')
# 0 56 names ('Vyalba', 'Lockwood', 'Heinrich', 'Naser', 'Yuzhanov', 'La', 'Issa', 'Windsor', 'Meeuwis', 'Shunsen') countries ('Russian', 'English', 'German', 'Arabic', 'Russian', 'Vietnamese', 'Arabic', 'English', 'Dutch', 'Japanese')
# 0 57 names ('Srour', 'Ahn', 'Langenberg', 'Lagomarsino', 'Rishitnik', 'Serchuk', 'Samuels', 'Hodder', 'Harkov', 'Vogel') countries ('Arabic', 'Korean', 'German', 'Italian', 'Russian', 'Russian', 'English', 'English', 'Russian', 'German')
# 0 58 names ('Tadhgan', 'Livadny', 'Pavlichenko', 'Davidenkov', 'Ngai', 'Tuma', 'Muzarev', 'Maryanov', 'Togulev', 'Vyahirev') countries ('Irish', 'Russian', 'Russian', 'Russian', 'Korean', 'Arabic', 'Russian', 'Russian', 'Russian', 'Russian')
# 0 59 names ('Mordvin', 'Kagabu', 'Velikopolsky', 'Mindlin', 'Dobrusin', 'Prigov', 'Danich', 'Her', 'Rovinsky', 'Turbai') countries ('Russian', 'Japanese', 'Russian', 'Russian', 'Russian', 'Russian', 'Russian', 'Russian', 'Russian', 'Russian')
# 0 60 names ('Yuzgin', 'Maalouf', 'Andryushin', 'Ruadh', 'Lishansky', 'Otlivschikov', 'Tets', 'Bakhchivandzhi', 'Chkhenkeli', 'Schirmer') countries ('Russian', 'Arabic', 'Russian', 'Irish', 'Russian', 'Russian', 'Russian', 'Russian', 'Russian', 'German')
# 0 61 names ('Waller', 'Entus', 'Tomeev', 'Djanibekov', 'Finnegan', 'Walls', 'Lyon', 'Yablontsev', 'Ashwell', 'Maalouf') countries ('English', 'Russian', 'Russian', 'Russian', 'Irish', 'English', 'Dutch', 'Russian', 'English', 'Arabic')
# 0 62 names ('Baba', 'Gorchinsky', 'Kijek', 'Botros', 'Likholat', 'Hardaev', 'Touma', 'Maalouf', 'Salvage', 'Portner') countries ('Arabic', 'Russian', 'Polish', 'Arabic', 'Russian', 'Russian', 'Arabic', 'Arabic', 'French', 'German')
# 0 63 names ('Zhvykin', 'Fakhoury', 'Zhemchujnikov', 'Shalnikov', 'Nesis', 'Lancaster', 'Oshima', 'Egarmin', 'Tuma', 'Turlapov') countries ('Russian', 'Arabic', 'Russian', 'Russian', 'Russian', 'English', 'Japanese', 'Russian', 'Arabic', 'Russian')
# 0 64 names ('Hanbikov', 'Kasprzak', 'Bitar', 'Dikikh', 'Abramtchuk', 'Hulhachiev', 'Anufrienko', 'Jijemsky', 'Grosul', 'Novosadsky') countries ('Russian', 'Polish', 'Arabic', 'Russian', 'Russian', 'Russian', 'Russian', 'Russian', 'Russian', 'Russian')
# 0 65 names ('Zheronkin', 'Sierzant', 'Govyrin', 'Bakai', 'Tani', 'Kapoor', 'Kabalin', 'Romagnoli', 'Tsvylev', 'Holyavin') countries ('Russian', 'Polish', 'Russian', 'Russian', 'Japanese', 'English', 'Russian', 'Italian', 'Russian', 'Russian')
# 0 66 names ('Milward', 'Mohnatsky', 'Bagdatiev', 'Hierro', 'Mkrtumyan', 'Fertig', 'Adjalov', 'Gordon', 'Assaf', 'Jaskolski') countries ('English', 'Russian', 'Russian', 'Spanish', 'Russian', 'German', 'Russian', 'Scottish', 'Arabic', 'Polish')
# 0 67 names ('Lawa', 'Yoshida', 'Jameson', 'Batukov', 'Satake', 'Bergfalk', 'Cham', 'Podshivalov', 'Herodes', 'Malecha') countries ('Czech', 'Japanese', 'English', 'Russian', 'Japanese', 'German', 'Arabic', 'Russian', 'Czech', 'Czech')
# 0 68 names ('Djarimov', 'Nader', 'Otsing', 'Bahtiyaroff', 'Chekomasov', 'Handokhin', 'Babayants', 'Fabian', 'Bartolomeo', 'Gasich') countries ('Russian', 'Arabic', 'Russian', 'Russian', 'Russian', 'Russian', 'Russian', 'French', 'Italian', 'Russian')
# 0 69 names ('Yafaev', 'Vakulko', 'Musatov', 'Robertson', 'Vitram', 'Nakahara', 'Kirtley', 'Charge', 'Turchin', 'Millard') countries ('Russian', 'Russian', 'Russian', 'English', 'Russian', 'Japanese', 'English', 'English', 'Russian', 'English')
# 0 70 names ('Lockett', 'Vygotsky', 'Bain', 'Muir', 'Moghadam', 'Pendyuhov', 'Albero', 'Dubin', 'Ustkachkintsev', 'Vitoshnov') countries ('English', 'Russian', 'English', 'English', 'Arabic', 'Russian', 'Italian', 'Russian', 'Russian', 'Russian')
# 0 71 names ('Ri', 'Gataullin', 'Ochoa', 'Dreschner', 'Lotter', 'Jakhot', 'Ridgway', 'Romijn', 'Shirinkin', 'Andreyanov') countries ('Korean', 'Russian', 'Spanish', 'German', 'Russian', 'Russian', 'English', 'Dutch', 'Russian', 'Russian')
# 0 72 names ('Shirkovets', 'Etherton', 'Jo', 'Chung', 'Elinson', 'Schitsyn', 'Silva', 'Kloeten', 'Babusenko', 'Dzhahaya') countries ('Russian', 'English', 'Japanese', 'Korean', 'Russian', 'Russian', 'Portuguese', 'Dutch', 'Russian', 'Russian')
# 0 73 names ('Babinov', 'Salib', 'Kudara', 'Eikhfeld', 'Porhunov', 'Long', 'Gulaya', 'Nosenko', 'Likhodedov', 'Ellery') countries ('Russian', 'Arabic', 'Japanese', 'Russian', 'Russian', 'English', 'Russian', 'Russian', 'Russian', 'English')
# 0 74 names ('Yoshikawa', 'Shaidullin', 'Pesaro', 'Simecek', 'Cao', 'Morandi', 'Novosiltsov', 'Salvai', 'Kouri', 'Raikhelgauz') countries ('Japanese', 'Russian', 'Italian', 'Czech', 'Chinese', 'Italian', 'Russian', 'Italian', 'Arabic', 'Russian')
# 0 75 names ('Vanstein', 'Bilias', 'Antoun', 'Tselibeev', 'Tsveiba', 'Tsapelik', 'Nutrihin', 'Iemochi', 'Brzezicki', 'Angelopoulos') countries ('Russian', 'Greek', 'Arabic', 'Russian', 'Russian', 'Russian', 'Russian', 'Japanese', 'Polish', 'Greek')
# 0 76 names ('Shikitei', 'Kremlicka', 'Kirchner', 'Chertolyas', 'Grimes', 'Gafurov', 'Vanykin', 'Zhiharevitch', 'Laurenz', 'Bolivar') countries ('Japanese', 'Czech', 'German', 'Russian', 'English', 'Russian', 'Russian', 'Russian', 'German', 'Spanish')
# 0 77 names ('Ranson', 'Makushok', 'Seaghdha', 'Moghadam', 'Tokuoka', 'Sanjo', 'Fortunatov', 'Crawley', 'Chapko', 'Aboev') countries ('English', 'Russian', 'Irish', 'Arabic', 'Japanese', 'Japanese', 'Russian', 'English', 'Russian', 'Russian')
# 0 78 names ('Tikhodeev', "V'Unnikov", 'Boutros', 'Furnell', 'Prigojy', 'Zherebovich', 'Parrott', 'Murylev', 'Opizka', 'Shenfeld') countries ('Russian', 'Russian', 'Arabic', 'English', 'Russian', 'Russian', 'English', 'Russian', 'Czech', 'Russian')
# 0 79 names ('Abel', 'Ieyasu', 'Penners', 'Adiev', 'Aloia', 'Vaniev', 'Rjanitsin', 'Fakhoury', 'Kau', 'Eizen') countries ('French', 'Japanese', 'Dutch', 'Russian', 'Italian', 'Russian', 'Russian', 'Arabic', 'Chinese', 'Russian')
# 0 80 names ('Atiyeh', 'Iggleden', 'Gagen', 'Vinding', 'Dael', 'Bowles', 'Shalhoub', 'Galda', 'Turgenev', 'Kaufer') countries ('Arabic', 'English', 'Russian', 'Russian', 'Dutch', 'English', 'Arabic', 'Russian', 'Russian', 'German')
# 0 81 names ('Nakamura', 'Naser', 'Blaise', 'Leal', 'Kesl', 'Nepi', 'Rahal', 'Rochev', 'Tobulinsky', 'Landau') countries ('Japanese', 'Arabic', 'French', 'English', 'Czech', 'Italian', 'Arabic', 'Russian', 'Russian', 'German')
# 0 82 names ('Seif', 'Ghannam', 'Briggs', 'Bitar', 'Gorski', 'Jagovenko', 'Steuben', 'Svotak', 'Homa', 'Kitamura') countries ('Arabic', 'Arabic', 'English', 'Arabic', 'Polish', 'Russian', 'German', 'Czech', 'Russian', 'Japanese')
# 0 83 names ('Yudochkin', 'Jenner', 'Antonopoulos', 'Pontovich', 'Antar', 'Janoch', 'Pavlinsky', 'Avdienko', 'Tkachuk', 'Shamakin') countries ('Russian', 'English', 'Greek', 'Russian', 'Arabic', 'Czech', 'Russian', 'Russian', 'Russian', 'Russian')
# 0 84 names ('Ganim', 'Montero', 'Davidson', 'Jjenov', 'Jermy', 'Valnev', 'Laps', 'Leimon', 'Gafin', 'Vinterfeldt') countries ('Arabic', 'Spanish', 'English', 'Russian', 'English', 'Russian', 'Russian', 'Russian', 'Russian', 'Russian')
# 0 85 names ('Jalnin', 'Keys', 'Hogg', 'Glass', 'Bekshansky', 'Ryzhey', 'Grosshopf', 'Gukasov', 'Adamo', 'Basso') countries ('Russian', 'English', 'English', 'English', 'Russian', 'Russian', 'Russian', 'Russian', 'Italian', 'Italian')
# 0 86 names ('Jatskovsky', 'De sauveterre', 'Voznesensky', 'Wasem', 'Alagona', 'Getselev', 'Makshakov', 'Utley', 'Guirguis', 'Sobol') countries ('Russian', 'French', 'Russian', 'Arabic', 'Italian', 'Russian', 'Russian', 'English', 'Arabic', 'Polish')
# 0 87 names ('Khouri', 'Axon', 'Martirosov', 'Iskritsky', 'Jaivoronok', 'Tsujimoto', 'Katzan', 'Dzhibladze', 'Limoshin', 'Bancroft') countries ('Arabic', 'English', 'Russian', 'Russian', 'Russian', 'Japanese', 'Russian', 'Russian', 'Russian', 'English')
# 0 88 names ('Averichkin', 'Ryan', 'Hoshino', 'Fargher', 'Averitchkin', 'Evison', 'Hadad', 'Valberh', 'Dunn', 'Mojin') countries ('Russian', 'English', 'Japanese', 'English', 'Russian', 'English', 'Arabic', 'Russian', 'English', 'Russian')
# 0 89 names ('Nood', 'Vozilov', 'Zogby', 'Jurin', 'Chi', 'Gomulka', 'Millward', 'Ustinkin', 'Takecare', 'Aliberti') countries ('English', 'Russian', 'Arabic', 'Russian', 'Korean', 'Polish', 'English', 'Russian', 'Japanese', 'Italian')
# 0 90 names ('Jakimenko', 'Adelhanoff', 'Hoffman', 'Atiyeh', 'Vanzha', 'Kabakchi', 'Shakhno', 'Zinchenko', 'Bian', 'Arita') countries ('Russian', 'Russian', 'German', 'Arabic', 'Russian', 'Russian', 'Russian', 'Russian', 'Chinese', 'Japanese')
# 0 91 names ('Tsunoda', 'Tcharuhin', 'Lystsov', 'Androvsky', 'Elvin', 'Hakhulin', 'Ellis', 'Sherry', 'Durr', 'Ageenko') countries ('Japanese', 'Russian', 'Russian', 'Russian', 'English', 'Russian', 'English', 'English', 'German', 'Russian')
# 0 92 names ('Kofel', 'Wegner', 'Chartorizhsky', 'Hampson', 'Portnoy', 'Etchells', 'Ageevets', 'Molochkov', 'Hlynov', 'Xin') countries ('Czech', 'German', 'Russian', 'English', 'Russian', 'English', 'Russian', 'Russian', 'Russian', 'Chinese')
# 0 93 names ('Baibakov', 'Sarraf', 'Derman', 'Vainer', 'Fiskin', 'Grimaldi', 'Kanavos', 'Hadad', 'Shirinyants', 'Daty') countries ('Russian', 'Arabic', 'Russian', 'Russian', 'Russian', 'Italian', 'Greek', 'Arabic', 'Russian', 'Russian')
# 0 94 names ('Isa', 'Herriot', 'Imendaev', 'Gorman', 'Crane', 'Tulubensky', 'Rutshtein', 'Slepicka', 'Jukhimenko', 'Lines') countries ('Arabic', 'French', 'Russian', 'English', 'English', 'Russian', 'Russian', 'Czech', 'Russian', 'English')
# 0 95 names ('Vedenkin', 'Koenig', 'Mohov', 'Daher', 'Onenko', 'Kurohiko', 'Walkenhorst', 'Chikun', 'Glaznev', 'Tzalyhin') countries ('Russian', 'German', 'Russian', 'Arabic', 'Russian', 'Japanese', 'German', 'Russian', 'Russian', 'Russian')
# 0 96 names ('Mondo', 'Zhakov', 'Manfredonia', 'Boutros', 'Mcintyre', 'Nosaka', 'Dillon', 'Dohman', 'Marshalko', 'Tikhonravov') countries ('Italian', 'Russian', 'Italian', 'Arabic', 'Scottish', 'Japanese', 'English', 'German', 'Russian', 'Russian')
# 0 97 names ('Peltser', 'Pavlyuchkov', 'Lupalenko', 'Avilkin', 'Vakulovsky', 'Beaulieu', 'Awilkin', 'Quraishi', 'Yamahata', 'Urogataya') countries ('Russian', 'Russian', 'Russian', 'Russian', 'Russian', 'French', 'Russian', 'Arabic', 'Japanese', 'Japanese')
# 0 98 names ('Bawin', 'Kaza', 'Tulebaev', 'Kalinka', 'Babin', 'Sylvester', 'Dean', 'Davlyatov', 'Zuraw', 'Hesin') countries ('Russian', 'Japanese', 'Russian', 'Russian', 'Russian', 'English', 'English', 'Russian', 'Polish', 'Russian')
# 0 99 names ('Chastain', 'Guirguis', 'Haziahmetov', 'Vincent', 'Szweda', 'Winter', 'Zaslavets', 'Landi', 'Toichkin', 'Rutberg') countries ('French', 'Arabic', 'Russian', 'French', 'Polish', 'German', 'Russian', 'Italian', 'Russian', 'Russian')
# 0 100 names ('Suh', 'Mustafa', 'Vyguzov', 'Wears', 'Zhizhnov', 'Okakura', 'Tsander', 'Horoshilov', 'Wedekind', 'Avgustoff') countries ('Korean', 'Arabic', 'Russian', 'English', 'Russian', 'Japanese', 'Russian', 'Russian', 'German', 'Russian')
# 0 101 names ('Rukhlin', 'Ruhimovich', 'Goddard', 'Barabolya', 'Haik', 'Vintov', 'Odriscoll', 'Deeb', 'Hanania', 'Spears') countries ('Russian', 'Russian', 'English', 'Russian', 'Arabic', 'Russian', 'English', 'Arabic', 'Arabic', 'English')
# 0 102 names ('Morcos', 'Goncharuk', 'Karamorita', 'Kozlow', 'Quraishi', 'Hajjar', 'Neyland', 'Uhobotin', 'Orlando', 'Chapman') countries ('Arabic', 'Russian', 'Japanese', 'Polish', 'Arabic', 'Arabic', 'English', 'Russian', 'Italian', 'English')
# 0 103 names ('Tchekonov', 'Macleod', 'Glaziev', 'Adamski', 'Ventimiglia', 'Harb', 'Mifsud', 'Edon', 'Eldridge', 'Re') countries ('Russian', 'English', 'Russian', 'Russian', 'Italian', 'Arabic', 'Arabic', 'English', 'English', 'Italian')
# 0 104 names ('Macshuibhne', 'Juhno', 'Naifeh', 'Kaul', 'Kett', 'Hart', 'Talzi', 'Eikhenbaum', 'Wirth', 'Fotopoulos') countries ('Irish', 'Russian', 'Arabic', 'English', 'English', 'English', 'Russian', 'Russian', 'German', 'Greek')
# 0 105 names ('Thornton', 'Miodushevsky', 'Pekhterev', 'Khoury', 'Greenway', 'Jia', 'Johov', 'Sarkis', 'Bustillo', 'Artyuhov') countries ('English', 'Russian', 'Russian', 'Arabic', 'English', 'Chinese', 'Russian', 'Arabic', 'Spanish', 'Russian')
# 0 106 names ('Bakhurin', 'Vyazovchenko', 'Freedman', 'Lezhankin', 'Takemura', 'Dobropolsky', 'Oconnor', 'Badalyants', 'Yakubik', 'Bader') countries ('Russian', 'Russian', 'English', 'Russian', 'Japanese', 'Russian', 'English', 'Russian', 'Russian', 'Russian')
# 0 107 names ('Geldart', 'Anikushin', 'Matasov', 'Pyhteev', 'Haruguchi', 'Montague', 'Picha', 'Gordon', 'Robson', 'Babikoff') countries ('English', 'Russian', 'Russian', 'Russian', 'Japanese', 'English', 'Czech', 'Russian', 'English', 'Russian')
# 0 108 names ('Abdurahmanov', 'Amantea', 'Chernov', 'Kearsley', 'Basovsky', 'Lysansky,', 'Bonner', 'Utton', 'Santiago', 'Bastrygin') countries ('Russian', 'Italian', 'Russian', 'English', 'Russian', 'Russian', 'French', 'English', 'Portuguese', 'Russian')
# 0 109 names ('Adiloff', 'Macaulay', 'Vampilov', 'Horujy', 'Matsigura', 'Hochberg', 'Janpolsky', 'Turusin', 'Nagata', 'Uchaikin') countries ('Russian', 'English', 'Russian', 'Russian', 'Russian', 'German', 'Russian', 'Russian', 'Japanese', 'Russian')
# 0 110 names ('Arato', 'Haddad', 'Germain', 'Eggby', 'Mustafa', 'Biryukov', 'Shamon', 'Bulgarelli', 'Kiddle', 'Bush') countries ('Japanese', 'Arabic', 'French', 'English', 'Arabic', 'Russian', 'Arabic', 'Italian', 'English', 'English')
# 0 111 names ('Bahar', 'Sasakawa', 'Jitarev', 'Gasselblat', 'Derjavets', 'Flaherty', 'Biddle', 'Albert', 'Tzapenko', 'Scott') countries ('Arabic', 'Japanese', 'Russian', 'Russian', 'Russian', 'English', 'English', 'French', 'Russian', 'Scottish')
# 0 112 names ('Brune', 'Mohren', 'Pokhilko', 'Watters', 'Bishara', 'Vyazmikin', 'Vernon', 'Obysov', 'Cisternino', 'Monette') countries ('German', 'Dutch', 'Russian', 'English', 'Arabic', 'Russian', 'English', 'Russian', 'Italian', 'French')
# 0 113 names ('Bakulev', 'Weichert', 'Rokhmistrov', 'Matheson', 'Belilovsky', 'Gudvan', 'Jiltsov', 'Jubb', 'Brotz', 'Malouf') countries ('Russian', 'Czech', 'Russian', 'English', 'Russian', 'Russian', 'Russian', 'English', 'German', 'Arabic')
# 0 114 names ('Mifsud', 'Velyashev', 'Vingilevsky', 'Aeschelman', 'Fairclough', 'Spiller', 'Inouye', 'Biondi', 'Granikov', 'Viselov') countries ('Arabic', 'Russian', 'Russian', 'German', 'English', 'English', 'Japanese', 'Italian', 'Russian', 'Russian')
# 0 115 names ('Elstone', 'Cherov', 'Hagurov', 'Rekunov', 'Abankin', 'Jandutkin', 'Wolter', 'Hanika', 'Kalabuhov', 'Broadley') countries ('English', 'Russian', 'Russian', 'Russian', 'Russian', 'Russian', 'German', 'Czech', 'Russian', 'English')
# 0 116 names ('Hapchaev', 'To The First Page', 'Meakin', 'Badanoff', 'Lowes', 'Canne', 'Davenport', 'Simpson', 'Gladyshev', 'Tzah') countries ('Russian', 'Russian', 'English', 'Russian', 'English', 'Dutch', 'English', 'English', 'Russian', 'Russian')
# 0 117 names ('Pechenev', 'Panayiotopoulos', 'Sabbag', 'Richman', 'Maxwell', 'Barros', 'Shadid', 'Adam', 'Matsyuk', 'Glubokovsky') countries ('Russian', 'Greek', 'Arabic', 'English', 'English', 'Portuguese', 'Arabic', 'English', 'Russian', 'Russian')
# 0 118 names ('Allman', 'Avdakoff', 'Hatton', 'Vaksel', 'Hajjar', 'Tupikov', 'Rothwell', 'Llewellyn', 'Daniau', 'Tovstolujsky') countries ('English', 'Russian', 'English', 'Russian', 'Arabic', 'Russian', 'English', 'English', 'French', 'Russian')
# 0 119 names ('Sarto', 'Verba', 'Deighton', 'Hopkins', 'Haritonenko', 'Djelepov', 'Hicks', 'Agursky', 'Ahern', 'Homatsky') countries ('Italian', 'Russian', 'English', 'English', 'Russian', 'Russian', 'English', 'Russian', 'English', 'Russian')
# 0 120 names ('Yagudin', 'Fiore', 'Juikov', 'Donkin', 'Junin', 'Fumihiko', 'Sumitimo', 'Schultze', 'Zhabykin', 'Yabrov') countries ('Russian', 'Italian', 'Russian', 'English', 'Russian', 'Japanese', 'Japanese', 'German', 'Russian', 'Russian')
# 0 121 names ('Gerhard', 'Tan', 'Atramov', 'Veasey', 'Harb', 'Martyshin', 'Lejikov', 'Gorski', 'Vasyutsky', 'Vertelko') countries ('German', 'Chinese', 'Russian', 'English', 'Arabic', 'Russian', 'Russian', 'Russian', 'Russian', 'Russian')
# 0 122 names ('Mihelson', 'Qureshi', 'Leites', 'Acerbi', 'Hanok', 'Rypka', 'Riva', 'Mukusev', 'Zhemlikhanov', 'Tahan') countries ('Russian', 'Arabic', 'Russian', 'Italian', 'Russian', 'Czech', 'Italian', 'Russian', 'Russian', 'Arabic')
# 0 123 names ('Ba', 'Makhno', 'Malouf', 'Quirk', 'Zhukov', 'Allcott', 'Chukhnin', 'Lefebvre', 'Preece', 'Nemoto') countries ('Arabic', 'Russian', 'Arabic', 'English', 'Russian', 'English', 'Russian', 'French', 'English', 'Japanese')
# 0 124 names ('Hoteev', 'Ustyantsev', 'Bakaloff', 'Khouri', 'Handal', 'Abdulrakhmanoff', 'Zhevolozhnov', 'Jashkov', 'Kelsey', 'Castro') countries ('Russian', 'Russian', 'Russian', 'Arabic', 'Arabic', 'Russian', 'Russian', 'Russian', 'English', 'Spanish')
# 0 125 names ('Till', 'Lihonosov', 'Urbanovska', 'Fermi', 'Gorbulin', 'Damhan', 'Minyaichev', 'Tatlow', 'Takagawa', 'Jvykin') countries ('Czech', 'Russian', 'Czech', 'Italian', 'Russian', 'Irish', 'Russian', 'English', 'Japanese', 'Russian')
# 0 126 names ('Yakhaev', 'Berezitsky', 'Abalmasoff', 'Sip', 'Kaburneev', 'Petticrew', 'Ryzhov', 'Hadad', 'Badich', 'Hollis') countries ('Russian', 'Russian', 'Russian', 'Czech', 'Russian', 'English', 'Russian', 'Arabic', 'Russian', 'English')
# 0 127 names ('Grizodubov', 'Mokin', 'Galepa', 'Bellamy', 'Narahashi', 'Lozhchenko', 'Tuma', 'Millar', 'Elepov', 'Naifeh') countries ('Russian', 'Russian', 'Russian', 'French', 'Japanese', 'Russian', 'Arabic', 'Scottish', 'Russian', 'Arabic')
# 0 128 names ('Tsidilin', 'Ba', 'Boulos', 'Longworth', 'Vedernikov', 'Reyes', 'Vinichenko', 'Strong', 'Bandoni', 'Zhitinev') countries ('Russian', 'Arabic', 'Arabic', 'English', 'Russian', 'English', 'Russian', 'English', 'Italian', 'Russian')
# 0 129 names ('Davydenko', 'Morimoto', 'Senmatsu', 'Isnard', 'Paimuhin', 'Bawvykin', "O'Brian", 'Said', 'Baitchorov', 'Haine') countries ('Russian', 'Japanese', 'Japanese', 'English', 'Russian', 'Russian', 'Irish', 'Arabic', 'Russian', 'English')
# 0 130 names ('Grose', 'Yakhlakov', 'Kranz', 'Anipkin', 'Said', 'Rekitar', 'Li', 'Antoun', 'Saliba', 'Limar') countries ('English', 'Russian', 'Dutch', 'Russian', 'Arabic', 'Russian', 'Korean', 'Arabic', 'Arabic', 'Russian')
# 0 131 names ('Martelli', 'Jabrev', 'Tikhonitsky', 'Forsythe', 'Yudkin', 'Turkevich', 'Lurie', 'Vanke', 'Jernovoy', 'Lutfullin') countries ('Italian', 'Russian', 'Russian', 'English', 'Russian', 'Russian', 'Russian', 'Russian', 'Russian', 'Russian')
# 0 132 names ('Pogosyan', 'Chekhluev', 'Agumaa', 'Baglai', 'Siskin', 'Antoun', 'Hadad', 'Lapin', 'Bowers', 'Saller') countries ('Russian', 'Russian', 'Russian', 'Russian', 'German', 'Arabic', 'Arabic', 'Russian', 'English', 'German')
# 0 133 names ('Urbina', 'Aiza', 'Mogilevsky', 'Villaverde', 'Vlahos', 'Perkins', 'Kuntz', 'Kasahara', 'Kalachov', 'Hagino') countries ('Spanish', 'Spanish', 'Russian', 'Spanish', 'Greek', 'English', 'German', 'Japanese', 'Russian', 'Japanese')
# 0 134 names ('Bishara', 'Mikhilev', 'Abba', 'Rovner', 'Carter', 'Jilyardy', 'Nunes', 'Zhivov', 'Tuzin', 'Doev') countries ('Arabic', 'Russian', 'Italian', 'Russian', 'English', 'Russian', 'Portuguese', 'Russian', 'Russian', 'Russian')
# 0 135 names ('Beck', 'Shaikov', 'Seif', 'Harev', 'Minih', 'Ekin', 'Tsigra', 'Bilenko', 'Marconi', 'Fedotov') countries ('German', 'Russian', 'Arabic', 'Russian', 'Russian', 'Russian', 'Russian', 'Russian', 'Italian', 'Russian')
# 0 136 names ('Shaw', 'Nader', 'Evstafiev', 'Avdulov', 'Featherstone', 'Kachimov', 'Jakhin', 'Daher', 'Batuev', 'Ross') countries ('Chinese', 'Arabic', 'Russian', 'Russian', 'English', 'Russian', 'Russian', 'Arabic', 'Russian', 'English')
# 0 137 names ('Hartukov', 'Leibovsky', 'Lenz', 'Valkin', 'Humphreys', 'Mkrtchan', 'Saifulaev', 'Vadbolski', 'Britton', 'Gray') countries ('Russian', 'Russian', 'German', 'Russian', 'English', 'Russian', 'Russian', 'Russian', 'English', 'Scottish')
# 0 138 names ('Bhrighde', 'Kalb', 'Zhui', 'Jeffries', 'Gan', 'Harkness', 'Belotsvetov', 'Atiyeh', 'Lichagin', 'Batsev') countries ('Irish', 'Arabic', 'Chinese', 'English', 'Chinese', 'English', 'Russian', 'Arabic', 'Russian', 'Russian')
# 0 139 names ('Pape', 'Neave', 'Chagin', 'Achteren', 'Marusev', 'Moshenko', 'Nahas', 'Leroy', 'Harrison', 'Privalikhin') countries ('French', 'English', 'Russian', 'Dutch', 'Russian', 'Russian', 'Arabic', 'English', 'English', 'Russian')
# 0 140 names ('Minervin', 'Hung', 'Bazhev', 'Aart', 'Esmansky', 'Stites', 'Keight', 'Yamato', 'Schultheiss', 'Matsoukis') countries ('Russian', 'Korean', 'Russian', 'Dutch', 'Russian', 'Czech', 'English', 'Japanese', 'German', 'Greek')
# 0 141 names ('Saxton', 'Noggins', 'Liholat', 'Wilks', 'Zelenin', 'Shahurov', 'Kabanov', 'Bakuridze', 'Driver', 'Hayes') countries ('English', 'English', 'Russian', 'English', 'Russian', 'Russian', 'Russian', 'Russian', 'English', 'English')
# 0 142 names ('Travieso', 'Kartajev', 'Bitar', 'Molotilov', 'Vitorgan', 'Moreinis', 'Dmitrochenko', 'Lygach', 'De felice', 'Sommer') countries ('Spanish', 'Russian', 'Arabic', 'Russian', 'Russian', 'Russian', 'Russian', 'Russian', 'Italian', 'German')
# 0 143 names ('Halfin', 'Martinez', 'Munster', 'Eidelman', 'Mujitskikh', 'Shamurin', 'Wallace', 'Mushanaokoji', 'Absalyamoff', "O'Byrne") countries ('Russian', 'English', 'Russian', 'Russian', 'Russian', 'Russian', 'Scottish', 'Japanese', 'Russian', 'Irish')
# 0 144 names ('Jivoderov', 'Milford', 'Tankoshitsu', 'Zaruba', 'Nicholson', 'Zabala', 'Truhin', 'Ruzakov', 'Moghadam', 'Gladtsin') countries ('Russian', 'English', 'Japanese', 'Czech', 'English', 'Spanish', 'Russian', 'Russian', 'Arabic', 'Russian')
# 0 145 names ('Zherihin', 'Adlerberg', 'Packard', 'Baboshkin', 'Foster', 'Saliba', 'Teague', 'Marsky', 'Wharton', 'Halford') countries ('Russian', 'Russian', 'English', 'Russian', 'English', 'Arabic', 'Irish', 'Russian', 'English', 'English')
# 0 146 names ('Zhuromsky', 'Rademacher', 'Zhunin', 'Vinnik', 'Pohilevich', 'Ruda', 'Zhenovach', 'Avhimovich', 'Tchekhoev', 'Flater') countries ('Russian', 'German', 'Russian', 'Russian', 'Russian', 'Czech', 'Russian', 'Russian', 'Russian', 'German')
# 0 147 names ('Mahagonov', 'Nelyubin', 'Babadzhanoff', 'Buhr', 'Moshninov', 'Tang', 'Ableuhoff', 'Belostotsky', 'Schepkin', 'Bartonova') countries ('Russian', 'Russian', 'Russian', 'German', 'Russian', 'English', 'Russian', 'Russian', 'Russian', 'Czech')
# 0 148 names ('Steffen', 'Knott', 'Votke', 'Wickens', 'Nicoll', 'Imatkulov', 'Agalakoff', 'Tolbuhin', 'Stanford', 'Cockle') countries ('German', 'English', 'Czech', 'English', 'English', 'Russian', 'Russian', 'Russian', 'English', 'English')
# 0 149 names ('Hisamutdinov', 'Khoury', 'Cross', 'Doyle', 'Jarikhin', 'Musalatov', 'Mustafa', 'Schepin', 'Finochkin', 'Kalb') countries ('Russian', 'Arabic', 'English', 'Irish', 'Russian', 'Russian', 'Arabic', 'Russian', 'Russian', 'Arabic')
# 0 150 names ('Gui', 'Vinchevsky', 'Yun', 'Jadan', 'Azhnikoff', 'Pesek', 'Gaspari', 'Ghanem', 'Hrabak', 'Borghi') countries ('Chinese', 'Russian', 'Korean', 'Russian', 'Russian', 'Czech', 'Italian', 'Arabic', 'Czech', 'Italian')
# 0 151 names ('Fawn', 'Illing', 'Werlla', 'Bajinoff', 'Ryder', 'Mukomel', 'Lychakov', 'Aziz', 'Avkhimovich', 'Alesi') countries ('English', 'English', 'Czech', 'Russian', 'English', 'Russian', 'Russian', 'English', 'Russian', 'Italian')
# 0 152 names ('Grushka', 'Troekurov', 'Mihalchenko', 'Turuhin', 'Roper', 'Toktakhunov', 'Ebina', 'Naslednikov', 'Bahmin', 'Pillay') countries ('Russian', 'Russian', 'Russian', 'Russian', 'English', 'Russian', 'Japanese', 'Russian', 'Russian', 'English')
# 0 153 names ('Agramoff', 'Rogan', 'Demko', 'Wruck', 'Tsukioka', 'Makhlinsky', 'Shimuzu', 'Darlington', 'Schmidt', 'Garber') countries ('Russian', 'English', 'Czech', 'German', 'Japanese', 'Russian', 'Japanese', 'English', 'German', 'English')
# 0 154 names ('Remnev', 'Haitsin', 'Emberey', 'Phillips', 'De laurentis', 'Ironman', 'Yamanoue', 'Nagano', 'Yakunov', 'Tsyurko') countries ('Russian', 'Russian', 'English', 'English', 'Italian', 'English', 'Japanese', 'Japanese', 'Russian', 'Russian')
# 0 155 names ('Hilchevsky', 'Matsotsky', 'Bitar', 'Tahan', 'Stokes', 'Avakshin', 'Portelli', 'Abuzov', 'Khouri', 'Bazhanov') countries ('Russian', 'Russian', 'Arabic', 'Arabic', 'English', 'Russian', 'Italian', 'Russian', 'Arabic', 'Russian')
# 0 156 names ('Desjardins', 'Schroder', 'Alytsky', 'Ageikin', 'Bakshtanovski', 'Tseitlin', 'Taloverov', 'Kuai', 'Han', 'Belogorsky') countries ('French', 'German', 'Russian', 'Russian', 'Russian', 'Russian', 'Russian', 'Chinese', 'Korean', 'Russian')
# 0 157 names ('Vasianov', 'Ghanem', 'Neil', 'Juromsky', 'Charlott', 'Hyde', 'Hudoleev', 'Iturburua', 'Avdiewski', 'Vikhansky') countries ('Russian', 'Arabic', 'Irish', 'Russian', 'Czech', 'English', 'Russian', 'Spanish', 'Russian', 'Russian')
# 0 158 names ('Eedie', 'Rapallino', 'Jachmentsev', 'Tuma', 'Kassis', 'Halabi', 'Guirguis', 'Kimio', 'Hawkes', 'Jordan') countries ('English', 'Italian', 'Russian', 'Arabic', 'Arabic', 'Arabic', 'Arabic', 'Japanese', 'English', 'French')
# 0 159 names ('Chikhachev', 'Lotorev', 'Naifeh', 'Pierce', 'Harries', 'Assaf', 'Najjar', 'Lymarev', 'Chaldymov', 'Benivieni') countries ('Russian', 'Russian', 'Arabic', 'English', 'English', 'Arabic', 'Arabic', 'Russian', 'Russian', 'Italian')
# 0 160 names ('Yap', 'Hout', 'Likhonosov', 'Hakimi', 'Koole', 'Brunetti', 'Balakhovsky', 'Norville', 'Jemoitel', 'Kempson') countries ('Chinese', 'Dutch', 'Russian', 'Arabic', 'Dutch', 'Italian', 'Russian', 'English', 'Russian', 'English')
# 0 161 names ('Osullivan', 'ChyrgalOol', 'Brunton', 'Neverovsky', 'Abrahimov', 'Oleastro', 'Reardon', 'Potts', 'Adanet', 'Belikov') countries ('English', 'Russian', 'English', 'Russian', 'Russian', 'Spanish', 'English', 'English', 'English', 'Russian')
# 0 162 names ('Dobulevich', 'Tsvigun', 'Fukayama', 'Hashachih', 'Huajev', 'Virichev', 'Patzev', 'Rana', 'Coll', 'Talipov') countries ('Russian', 'Russian', 'Japanese', 'Russian', 'Russian', 'Russian', 'Russian', 'Italian', 'English', 'Russian')
# 0 163 names ('Hijnyak', 'Vilensky', 'Shel', 'Schroter', 'Gunther', 'Black', 'Jenicek', 'Timashev', 'Atazhakhov', 'Petrov') countries ('Russian', 'Russian', 'Russian', 'German', 'German', 'Scottish', 'Czech', 'Russian', 'Russian', 'Russian')
# 0 164 names ('Deribas', 'Deulenko', 'Hermann', 'Basara', 'Yudahin', 'Bagalei', 'Yakimets', 'Shengeliya', 'Najjar', 'Zimin') countries ('Russian', 'Russian', 'German', 'Arabic', 'Russian', 'Russian', 'Russian', 'Russian', 'Arabic', 'Russian')
# 0 165 names ('Schneider', 'Kaspar', 'Leck', 'Krol', 'Jeltoukhov', 'Hitrin', 'Law', 'Ferraro', 'Shamburkin', 'Jeverjeev') countries ('German', 'German', 'English', 'Polish', 'Russian', 'Russian', 'Chinese', 'Italian', 'Russian', 'Russian')
# 0 166 names ('Tansley', 'Garrard', 'Fujita', 'Acciai', 'Hlusov', 'Tos', 'Mikhaltsov', 'Evranov', 'Gudenko', 'Edgley') countries ('English', 'English', 'Japanese', 'Italian', 'Russian', 'Spanish', 'Russian', 'Russian', 'Russian', 'English')
# 0 167 names ('Kouri', 'Zherdev', 'Rokhin', 'Partington', 'Forsh', 'Kassis', 'Daher', 'Han', 'Dritsas', 'Fakhoury') countries ('Arabic', 'Russian', 'Russian', 'English', 'Russian', 'Arabic', 'Arabic', 'Vietnamese', 'Greek', 'Arabic')
# 0 168 names ('Jackson', 'Eccles', 'Christodoulou', 'Leikisman', 'Veligjanin', 'Di pietro', 'Eremchenko', 'Thach', 'Dolton', 'Sturm') countries ('English', 'English', 'Greek', 'Russian', 'Russian', 'Italian', 'Russian', 'Vietnamese', 'English', 'German')
# 0 169 names ('Saliba', 'Yasui', 'Yasutake', 'Grady', 'Zhirkov', 'Piccoli', 'Valentine', 'Dobrovsky', 'Mulin', 'Paduchev') countries ('Arabic', 'Japanese', 'Japanese', 'English', 'Russian', 'Italian', 'English', 'Russian', 'Russian', 'Russian')
# 0 170 names ('Makhinov', 'Dogel', 'Viharev', 'Bannister', 'Mahonov', 'Grozhantsev', 'Mikhalevich', 'Masanobu', 'Ryjanov', 'Modin') countries ('Russian', 'Russian', 'Russian', 'English', 'Russian', 'Russian', 'Russian', 'Japanese', 'Russian', 'Russian')
# 0 171 names ('Rompa', 'Uemura', 'Ustyujanin', 'Chuhanov', 'Youlden', 'Imamaliev', 'Yalovoi', "O'Dowd", 'Ventura', 'Osladil') countries ('Dutch', 'Japanese', 'Russian', 'Russian', 'English', 'Russian', 'Russian', 'Irish', 'Spanish', 'Czech')
# 0 172 names ('Baichoroff', 'Amari', 'Djikovich', 'Geht', 'Nevitsky', 'Antonts', 'Shahmaev', 'Crowe', 'Darsky', 'Duckworth') countries ('Russian', 'Arabic', 'Russian', 'Russian', 'Russian', 'Russian', 'Russian', 'English', 'Russian', 'English')
# 0 173 names ('Mukin', 'Luha', 'Marsh', 'Mackay', 'Jupanenko', 'Martin', 'Chong', 'Mccarthy', 'Ton', 'Shevtsov') countries ('Russian', 'Russian', 'English', 'Scottish', 'Russian', 'Scottish', 'English', 'English', 'Vietnamese', 'Russian')
# 0 174 names ('Islavin', "Zasyad'Ko", 'Kahaya', 'Jakuba', 'Asghar', 'Juan', 'Sioda', 'Atlas', 'Chukhin', 'Pettigrew') countries ('Russian', 'Russian', 'Japanese', 'Russian', 'Arabic', 'Chinese', 'Irish', 'Russian', 'Russian', 'French')
# 0 175 names ('Remikh', 'Crew', 'Agatov', 'Michel', 'Muzychka', 'Avdeenko', 'Konae', 'Valshin', 'Lynsmeier', 'Lyme') countries ('Russian', 'English', 'Russian', 'Dutch', 'Russian', 'Russian', 'Japanese', 'Russian', 'Czech', 'English')
# 0 176 names ('Katsibin', 'Lebidko', 'Luce', 'Essa', 'Harwood', 'Uhtomsky', 'Nahas', 'Beamish', 'Onuchin', 'Joss') countries ('Russian', 'Russian', 'English', 'Arabic', 'English', 'Russian', 'Arabic', 'English', 'Russian', 'English')
# 0 177 names ('Valkovoy', 'Vinius', 'Kay', 'Serak', 'Hamamoto', 'Hankeev', 'Pavsky', 'Falk', 'Lapenkov', 'Orton') countries ('Russian', 'Russian', 'English', 'Czech', 'Japanese', 'Russian', 'Russian', 'English', 'Russian', 'English')
# 0 178 names ('Stuber', 'Leon', 'Vedyakin', 'Mihailyants', 'Keith', 'Gartner', 'Shula', 'Janzhul', 'Shamarin', 'Gasymov') countries ('German', 'French', 'Russian', 'Russian', 'English', 'German', 'Czech', 'Russian', 'Russian', 'Russian')
# 0 179 names ('Kendell', 'Tsutomu', 'Pellenen', 'Otten', 'Sterling', 'Bazikov', 'Lawrie', 'Shain', 'Bachish', 'Antar') countries ('English', 'Japanese', 'Russian', 'English', 'English', 'Russian', 'English', 'Russian', 'Russian', 'Arabic')
# 0 180 names ('Ishihara', 'Abbatangelo', 'Usievich', 'Knightley', 'Adamidis', 'Abandonato', 'Porfiriev', 'Tanzi', 'Asker', 'Fearghal') countries ('Japanese', 'Italian', 'Russian', 'English', 'Greek', 'Italian', 'Russian', 'Italian', 'Arabic', 'Irish')
# 0 181 names ('Lawn', 'Kanaan', 'Ambrogi', 'Fedotiev', 'Power', 'Keffler', 'Getta', 'Jobst', 'Zinin', 'Vesnovsky') countries ('English', 'Arabic', 'Italian', 'Russian', 'Irish', 'English', 'Russian', 'Czech', 'Russian', 'Russian')
# 0 182 names ('Ainsworth', 'Connolly', 'Vertyankin', 'Mcelroy', 'Loyola', 'Najjar', 'Kalitin', 'Tromonin', 'Kokan', 'Kennedy') countries ('English', 'Irish', 'Russian', 'English', 'Spanish', 'Arabic', 'Russian', 'Russian', 'Japanese', 'Irish')
# 0 183 names ('Jokin', 'Muru', 'Naifeh', 'Bahelov', 'Lezhebokov', 'Schirovsky', 'Egonidis', 'Dovgalev', 'Nazario', 'Gunby') countries ('Russian', 'Russian', 'Arabic', 'Russian', 'Russian', 'Russian', 'Greek', 'Russian', 'Italian', 'English')
# 0 184 names ('Whitaker', 'Beloyartsev', 'Ganim', 'Valentinovich', 'Stark', 'Grohar', 'Chukhlov', 'Modenov', 'Yahlakov', 'Shalgin') countries ('English', 'Russian', 'Arabic', 'Russian', 'German', 'Russian', 'Russian', 'Russian', 'Russian', 'Russian')
# 0 185 names ('Guilmard', 'Adrol', 'Jatsunov', 'Francis', 'Shahmatov', 'Zhevanov', 'Juhtanov', 'Boutros', 'Chursin', 'Tulaikov') countries ('English', 'English', 'Russian', 'English', 'Russian', 'Russian', 'Russian', 'Arabic', 'Russian', 'Russian')
# 0 186 names ('Shadid', 'Vivas', 'Matzyuk', 'Yadrikhinsky', 'Padalkin', 'Badmaev', 'Kosmas', 'Stenger', 'Nitta', 'Dasios') countries ('Arabic', 'Spanish', 'Russian', 'Russian', 'Russian', 'Russian', 'Greek', 'German', 'Japanese', 'Greek')
# 0 187 names ('Quraishi', 'Zhloba', 'Vajenin', 'Baba', 'Jivaev', 'Asker', 'Maneates', 'Ratcliffe', 'Gagin', 'Huff') countries ('Arabic', 'Russian', 'Russian', 'Arabic', 'Russian', 'Arabic', 'Greek', 'English', 'Russian', 'German')
# 0 188 names ('Elms', 'Peterson', 'Donchenko', 'Cong', 'Vaskov', "O'Kelly", 'Ritter', 'Waterson', 'Kira', 'Gridchin') countries ('English', 'English', 'Russian', 'Chinese', 'Russian', 'Irish', 'German', 'English', 'Japanese', 'Russian')
# 0 189 names ('Fakhoury', 'Mathghamhain', 'Iijima', 'Abitov', 'Kone', 'Shamoon', 'Mokhosoev', 'Tuikov', 'Perez', 'Shalhoub') countries ('Arabic', 'Irish', 'Japanese', 'Russian', 'English', 'Arabic', 'Russian', 'Russian', 'Spanish', 'Arabic')
# 0 190 names ('Yanochkin', 'Jakovchenko', 'Dankov', 'Ko', 'Yanitsky', 'Salomon', 'Morra', 'Jivopistsev', 'Porva', 'Enomoto') countries ('Russian', 'Russian', 'Russian', 'Korean', 'Russian', 'Polish', 'Italian', 'Russian', 'Russian', 'Japanese')
# 0 191 names ('Kaliberda', 'Friedrich', 'Van', 'Tannous', 'Lyzhenkov', 'Ladyjensky', 'Overton', 'Bonhomme', "O'Mahoney", 'Seif') countries ('Russian', 'Czech', 'Vietnamese', 'Arabic', 'Russian', 'Russian', 'English', 'French', 'Irish', 'Arabic')
# 0 192 names ('Sisson', 'Karras', 'Gudojnik', 'Carpenter', 'Molodykh', 'Babakhanov', 'Zavorohin', 'Yakobson', 'Rick', 'Gallo') countries ('English', 'English', 'Russian', 'English', 'Russian', 'Russian', 'Russian', 'Russian', 'English', 'English')
# 0 193 names ('Demihov', 'Anuriev', 'Marr', 'Jakuschenko', 'Jabitsky', 'Lopez', 'Matsumoto', 'Dunning', 'Shamsiev', 'Bishara') countries ('Russian', 'Russian', 'English', 'Russian', 'Russian', 'English', 'Japanese', 'English', 'Russian', 'Arabic')
# 0 194 names ('Till', 'Colling', 'Pigott', 'Atamanenko', 'Morri', 'Kitoaji', 'Cabello', 'Frumkin', 'Bakhanov', 'Vacca') countries ('English', 'Czech', 'English', 'Russian', 'Japanese', 'Japanese', 'Spanish', 'Russian', 'Russian', 'Italian')
# 0 195 names ('Hutchinson', 'Yalchevsky', 'Kawamura', 'Tzarenkov', 'Townsley', 'Adarchenko', 'Jejel', 'Halatyan', 'Kassis', 'Kajahara') countries ('English', 'Russian', 'Japanese', 'Russian', 'English', 'Russian', 'Russian', 'Russian', 'Arabic', 'Japanese')
# ...
# evaluating trained model ...
#
# Test set: Accuracy: 5599/6700 (84%)
#
# Sung is Chinese
# Jungwoo is Russian
# Soojin is Czech
# Nako is Korean
#  53s] Train Epoch: 61 [2560/13374 (19%)]	Loss: 10.64
#  55s] Train Epoch: 61 [5120/13374 (38%)]	Loss: 11.37
#  57s] Train Epoch: 61 [7680/13374 (57%)]	Loss: 10.55
#  59s] Train Epoch: 61 [10240/13374 (77%)]	Loss: 10.61
#  1s] Train Epoch: 61 [12800/13374 (96%)]	Loss: 10.59
# evaluating trained model ...
#
# Test set: Accuracy: 5583/6700 (83%)
#
# Sung is Chinese
# Jungwoo is Russian
# Soojin is Czech
# Nako is Korean
#  4s] Train Epoch: 62 [2560/13374 (19%)]	Loss: 8.50
#  6s] Train Epoch: 62 [5120/13374 (38%)]	Loss: 9.25
#  8s] Train Epoch: 62 [7680/13374 (57%)]	Loss: 9.24
#  10s] Train Epoch: 62 [10240/13374 (77%)]	Loss: 9.85
#  12s] Train Epoch: 62 [12800/13374 (96%)]	Loss: 10.33
# evaluating trained model ...
#
# Test set: Accuracy: 5574/6700 (83%)
#
# Sung is Chinese
# Jungwoo is Russian
# Soojin is Czech
# Nako is Korean
#  15s] Train Epoch: 63 [2560/13374 (19%)]	Loss: 7.22
#  17s] Train Epoch: 63 [5120/13374 (38%)]	Loss: 8.26
#  19s] Train Epoch: 63 [7680/13374 (57%)]	Loss: 9.04
#  21s] Train Epoch: 63 [10240/13374 (77%)]	Loss: 9.69
#  22s] Train Epoch: 63 [12800/13374 (96%)]	Loss: 10.56
# evaluating trained model ...
#
# Test set: Accuracy: 5534/6700 (83%)
#
# Sung is Chinese
# Jungwoo is English
# Soojin is Dutch
# Nako is Korean
#  26s] Train Epoch: 64 [2560/13374 (19%)]	Loss: 11.11
#  28s] Train Epoch: 64 [5120/13374 (38%)]	Loss: 12.84
#  30s] Train Epoch: 64 [7680/13374 (57%)]	Loss: 16.48
#  31s] Train Epoch: 64 [10240/13374 (77%)]	Loss: 19.20
#  33s] Train Epoch: 64 [12800/13374 (96%)]	Loss: 21.39
# evaluating trained model ...
#
# Test set: Accuracy: 5534/6700 (83%)
#
# Sung is Chinese
# Jungwoo is English
# Soojin is Czech
# Nako is Korean
#  36s] Train Epoch: 65 [2560/13374 (19%)]	Loss: 24.91
#  38s] Train Epoch: 65 [5120/13374 (38%)]	Loss: 26.56
#  40s] Train Epoch: 65 [7680/13374 (57%)]	Loss: 29.18
#  42s] Train Epoch: 65 [10240/13374 (77%)]	Loss: 30.85
#  44s] Train Epoch: 65 [12800/13374 (96%)]	Loss: 32.51
# evaluating trained model ...
#
# Test set: Accuracy: 5535/6700 (83%)
#
# Sung is Chinese
# Jungwoo is Russian
# Soojin is